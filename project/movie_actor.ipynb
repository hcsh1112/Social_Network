# %%
import requests
from bs4 import BeautifulSoup
import re
import csv

'''
res = requests.get('https://en.wikipedia.org/wiki/Lists_of_American_films')
soup = BeautifulSoup(res.text)
y = 0 # only 2010~2017
for year in soup.find_all(href=re.compile("^/wiki/List_of_American_films_of_201\d")):
    print(year['href'])
    y = y + 1
    if y == 8 : break
'''

res = requests.get('https://en.wikipedia.org/wiki/List_of_American_films_of_2017')
soup = BeautifulSoup(res.text)
table = soup.find( "table", class_='wikitable sortable' )
FileName = soup.find('h1').string 
with open( FileName + '.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow([ 'Movie', 'actor' ])
    for tr in table.find_all( "tr" ) :
        stage = 1
        movie_name = ""
        actor_list = []
        try:
            for td in tr.find_all( "td" ):
                if stage == 1 :
                    print( 'movie_name= ' + td.find("a").text )
                    movie_name = td.find("a").text
                    
                elif stage == 3 :
                    for actor in td.find_all("a"):
                        print( 'actor= ' + actor.text )
                        actor_list.append(actor.text)
                stage = stage + 1
            
            writer.writerow([ movie_name , actor_list ])
            print( ' ')
        except:
            print( 'no element' )
# Out:
# c:\users\eca_lab\appdata\local\programs\python\python35\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file c:\users\eca_lab\appdata\local\programs\python\python35\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
#
# no element
# movie_name= Arsenal
# actor= Steven C. Miller
# actor= Adrian Grenier
# actor= Johnathon Schaech
# actor= Nicolas Cage
# actor= Christopher Coppola
# actor= Shea Buckner
# actor= John Cusack
#
# movie_name= Between Us
# actor= Olivia Thirlby
# actor= Ben Feldman
# actor= Adam Goldberg
# actor= Analeigh Tipton
# actor= Scott Haze
# actor= Peter Bogdanovich
# actor= Lesley Ann Warren
#
# no element
# movie_name= The Bye Bye Man
# actor= Stacy Title
# actor= Jonathan Penner
# actor= Douglas Smith
# actor= Doug Jones
# actor= Michael Trucco
# actor= Cressida Bonas
# actor= Lucien Laviscount
# actor= Carrie-Anne Moss
# actor= Faye Dunaway
#
# movie_name= Sleepless
# actor= Baran bo Odar
# actor= Andrea Berloff
# actor= Jamie Foxx
# actor= T.I.
# actor= Drew Sidora
# actor= Lloyd Banks
# actor= Gabrielle Union
# actor= David Harbour
# actor= Young Jeezy
# actor= Michelle Monaghan
# actor= Scoot McNairy
# actor= Sala Baker
#
# movie_name= 100 Streets
# actor= Idris Elba
# actor= Gemma Arterton
# actor= Charlie Creed-Miles
# actor= Franz Drameh
# actor= Kierston Wareing
# actor= Tom Cullen
# actor= Ken Stott
#
# movie_name= The Book of Love
# actor= Jason Sudeikis
# actor= Jessica Biel
# actor= Maisie Williams
# actor= Mary Steenburgen
# actor= Orlando Jones
# actor= Paul Reiser
#
# no element
# movie_name= xXx: Return of Xander Cage
# actor= D. J. Caruso
# actor= Vin Diesel
# actor= Samuel L. Jackson
# actor= Donnie Yen
# actor= Deepika Padukone
# actor= Kris Wu
# actor= Nina Dobrev
# actor= Tony Jaa
# actor= Ruby Rose
# actor= Toni Collette
# actor= Nicky Jam
# actor= Rory McCann
# actor= Al Sapienza
# actor= Michael Bisping
# actor= Ariadna Gutiérrez
# actor= Hermione Corfield
# no element
# movie_name= The Resurrection of Gavin Stone
# actor= Brett Dalton
# actor= Anjelah Johnson
# actor= Neil Flynn
# actor= Shawn Michaels
# actor= D. B. Sweeney
#
# movie_name= Trespass Against Us
# actor= Adam Smith
# actor= Michael Fassbender
# actor= Brendan Gleeson
# actor= Lyndsey Marshal
# actor= Killian Scott
#
# no element
# no element
# movie_name= Resident Evil: The Final Chapter
# actor= Paul W. S. Anderson
# actor= Milla Jovovich
# actor= Shawn Roberts
# actor= Ruby Rose
# actor= William Levy
# actor= Iain Glen
# actor= Eoin Macken
# actor= Lee Joon-gi
# actor= Ali Larter
#
# movie_name= Lost in Florence
# actor= Brett Dalton
# actor= Stana Katic
# actor= Alessandra Mastronardi
# actor= Alessandro Preziosi
# actor= Emily Atack
# actor= Rob Aramayo
#
# movie_name= I Am Michael
# actor= Justin Kelly
# actor= James Franco
# actor= Zachary Quinto
# actor= Emma Roberts
# actor= Charlie Carver
#
# movie_name= iBoy
# actor= Bill Milner
# actor= Maisie Williams
# actor= Miranda Richardson
# actor= Rory Kinnear
#
# no element
# movie_name= The Space Between Us
# actor= Peter Chelsom
# actor= Allan Loeb
# actor= Asa Butterfield
# actor= Britt Robertson
# actor= Gary Oldman
# actor= Carla Gugino
# actor= B. D. Wong
#
# movie_name= Youth in Oregon
# actor= Joel David Moore
# actor= Frank Langella
# actor= Billy Crudup
# actor= Christina Applegate
# actor= Nicola Peltz
# actor= Josh Lucas
# actor= Mary Kay Place
# actor= Alex Shaffer
#
# movie_name= I Am Not Your Negro
# actor= Raoul Peck
# actor= Samuel L. Jackson
#
# movie_name= Growing Up Smith
# actor= Frank Lotito
# actor= Jason Lee
# actor= Anjul Nigam
# actor= Brighton Sharbino
# actor= Hilarie Burton
#
# no element
# movie_name= Fifty Shades Darker
# actor= James Foley
# actor= Dakota Johnson
# actor= Jamie Dornan
# actor= Kim Basinger
# actor= Luke Grimes
# actor= Eloise Mumford
# actor= Max Martini
# actor= Eric Johnson
# actor= Bella Heathcote
# actor= Marcia Gay Harden
# actor= Rita Ora
#
# movie_name= John Wick: Chapter 2
# actor= Chad Stahelski
# actor= Derek Kolstad
# actor= Keanu Reeves
# actor= Common
# actor= Bridget Moynahan
# actor= Ian McShane
# actor= John Leguizamo
# actor= Ruby Rose
# actor= Laurence Fishburne
#
# no element
# no element
# movie_name= A Cure for Wellness
# actor= Gore Verbinski
# actor= Justin Haythe
# actor= Dane DeHaan
# actor= Mia Goth
# actor= Jason Isaacs
#
# movie_name= Fist Fight
# actor= Ice Cube
# actor= Charlie Day
# actor= Christina Hendricks
# actor= Dennis Haysbert
# actor= Tracy Morgan
# actor= Jillian Bell
# actor= Dean Norris
#
# movie_name= American Fable
# actor= Peyton Kennedy
# actor= Richard Schiff
# actor= Kip Pardue
# actor= Marci Miller
# actor= Gavin MacIntosh
# actor= Zuleikha Robinson
#
# movie_name= XX
# actor= Annie Clark
# actor= Karyn Kusama
# actor= Natalie Brown
# actor= Melanie Lynskey
# actor= Breeda Wool
# actor= Christina Kirk
#
# movie_name= Lovesong
# actor= So Yong Kim
# actor= Jena Malone
# actor= Riley Keough
# actor= Brooklyn Decker
# actor= Amy Seimetz
# actor= Marshall Chapman
# actor= Ryan Eggold
# actor= Rosanna Arquette
#
# no element
# movie_name= Rock Dog
# actor= Ash Brannon
# actor= Luke Wilson
# actor= Eddie Izzard
# actor= J. K. Simmons
# actor= Lewis Black
# actor= Kenan Thompson
# actor= Mae Whitman
# actor= Jorge Garcia
# actor= Matt Dillon
# actor= Sam Elliott
#
# movie_name= Collide
# actor= Eran Creevy
# actor= Nicholas Hoult
# actor= Felicity Jones
# actor= Anthony Hopkins
# actor= Ben Kingsley
#
# movie_name= The Girl with All the Gifts
# actor= Colm McCarthy
# actor= M.R. Carey
# actor= Gemma Arterton
# actor= Glenn Close
# actor= Paddy Considine
#
# movie_name= I Don't Feel at Home in This World Anymore
# actor= Macon Blair
# actor= Melanie Lynskey
# actor= Elijah Wood
# actor= David Yow
# actor= Jane Levy
# actor= Devon Graye
#
# no element
# no element
# movie_name= The Shack
# actor= Stuart Hazeldine
# actor= John Fusco
# actor= Sam Worthington
# actor= Radha Mitchell
# actor= Octavia Spencer
# actor= Graham Greene
#
# movie_name= Before I Fall
# actor= Ry Russo-Young
# actor= Maria Maggenti
# actor= Zoey Deutch
# actor= Halston Sage
# actor= Logan Miller
# actor= Kian Lawley
# actor= Elena Kampouris
# actor= Medalion Rahimi
# actor= Diego Boneta
# actor= Jennifer Beals
#
# movie_name= Table 19
# actor= Jeffrey Blitz
# actor= Jay Duplass
# actor= Mark Duplass
# actor= Anna Kendrick
# actor= Amanda Crew
# actor= Stephen Merchant
# actor= Lisa Kudrow
# actor= Wyatt Russell
# actor= Craig Robinson
# actor= Tony Revolori
# actor= June Squibb
#
# movie_name= The Last Word
# actor= Mark Pellington
# actor= Shirley MacLaine
# actor= Amanda Seyfried
#
# movie_name= Catfight
# actor= Onur Tukel
# actor= Alicia Silverstone
# actor= Anne Heche
# actor= Sandra Oh
# actor= Dylan Baker
# actor= Amy Hall
# actor= Craig Bierko
#
# movie_name= Donald Cried
# actor= Louisa Krause
# actor= Ted Arcidi
#
# no element
# movie_name= Burning Sands
# actor= Trevor Jackson
# actor= Alfre Woodard
# actor= Steve Harris
# actor= Trevante Rhodes
# actor= Serayah
#
# no element
# movie_name= The Belko Experiment
# actor= Greg McLean
# actor= James Gunn
# actor= John Gallagher Jr.
# actor= Tony Goldwyn
# actor= David Del Rio
#
# movie_name= Song to Song
# actor= Terrence Malick
# actor= Ryan Gosling
# actor= Michael Fassbender
# actor= Rooney Mara
# actor= Natalie Portman
# actor= Christian Bale
# actor= Cate Blanchett
# actor= Benicio del Toro
# actor= Val Kilmer
#
# movie_name= Atomica
# actor= Dominic Monaghan
# actor= Tom Sizemore
# actor= Sarah Habel
#
# movie_name= All Nighter
# actor= J. K. Simmons
# actor= Emile Hirsch
# actor= Analeigh Tipton
# actor= Taran Killam
# actor= Kristen Schaal
#
# movie_name= The Devil's Candy
# actor= Sean Byrne
# actor= Ethan Embry
# actor= Shiri Appleby
# actor= Pruitt Taylor Vince
# actor= Marco Perella
#
# no element
# movie_name= Life
# actor= Daniel Espinosa
# actor= Paul Wernick
# actor= Rhett Reese
# actor= Rebecca Ferguson
# actor= Jake Gyllenhaal
# actor= Ryan Reynolds
# actor= Hiroyuki Sanada
#
# movie_name= CHiPs
# actor= Dax Shepard
# actor= Michael Peña
# actor= Vincent D'Onofrio
# actor= Adam Brody
# actor= Rosa Salazar
# actor= Vida Guerra
# actor= Kristen Bell
# no element
# movie_name= Wilson
# actor= Craig Johnson
# actor= Daniel Clowes
# actor= Woody Harrelson
# actor= Laura Dern
# actor= Isabella Amara
# actor= Judy Greer
# actor= Cheryl Hines
# actor= Margo Martindale
# actor= David Warshofsky
#
# no element
# movie_name= Car Dogs
# actor= Adam Collis
# actor= Patrick J. Adams
# actor= George Lopez
# actor= Nia Vardalos
# actor= Octavia Spencer
# actor= Josh Hopkins
# actor= Dash Mihok
# actor= Chris Mulkey
# actor= Alessandra Torresani
# actor= Cory Hardrict
#
# no element
# no element
# movie_name= The Boss Baby
# actor= Tom McGrath
# actor= Michael McCullers
# actor= Alec Baldwin
# actor= Steve Buscemi
# actor= Tobey Maguire
# actor= Jimmy Kimmel
# actor= Lisa Kudrow
#
# movie_name= The Zookeeper's Wife
# actor= Niki Caro
# actor= Jessica Chastain
# actor= Johan Heldenbergh
# actor= Daniel Brühl
# actor= Michael McElhatton
# no element
# movie_name= The Blackcoat's Daughter
# actor= Oz Perkins
# actor= Emma Roberts
# actor= Kiernan Shipka
# actor= Lucy Boynton
# actor= Lauren Holly
# actor= James Remar
#
# movie_name= The Discovery
# actor= Charlie McDowell
# actor= Jason Segel
# actor= Rooney Mara
# actor= Robert Redford
# actor= Jesse Plemons
# actor= Riley Keough
#
# movie_name= Carrie Pilby
# actor= Susan Johnson
# actor= Bel Powley
# actor= Vanessa Bayer
# actor= Colin O'Donoghue
# actor= William Moseley
# actor= Jason Ritter
# actor= Gabriel Byrne
# actor= Nathan Lane
